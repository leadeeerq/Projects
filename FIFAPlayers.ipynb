# %% [markdown]
# <a href="https://colab.research.google.com/github/leadeeerq/Projects/blob/main/FIFAPlayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FIFA19 players

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ##Loading the data - FIFA19 Players

# %%
df = pd.read_csv('/content/drive/MyDrive/Projekty/FIFA/fifa_data.csv')

# %% [markdown]
# ##Exploring the data

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %% [markdown]
# ####Polish players

# %%
df_polish = df[df['Nationality'] == 'Poland']
df_polish.head()
# Out:
#      Unnamed: 0      ID            Name  Age  \
# 10           10  188545  R. Lewandowski   29
# 92           92  186153     W. Szczęsny   28
# 202         202  190547         K. Glik   30
# 340         340  210406    P. Zieliński   24
# 350         350  205175        A. Milik   24
#
#                                               Photo Nationality  \
# 10   https://cdn.sofifa.org/players/4/19/188545.png      Poland
# 92   https://cdn.sofifa.org/players/4/19/186153.png      Poland
# 202  https://cdn.sofifa.org/players/4/19/190547.png      Poland
# 340  https://cdn.sofifa.org/players/4/19/210406.png      Poland
# 350  https://cdn.sofifa.org/players/4/19/205175.png      Poland
#
#                                     Flag  Overall  Potential  \
# 10   https://cdn.sofifa.org/flags/37.png       90         90
# 92   https://cdn.sofifa.org/flags/37.png       85         87
# 202  https://cdn.sofifa.org/flags/37.png       83         83
# ...

# %% [markdown]
# ####The best nationalities

# %%
df_nationalities = df.copy()
df_nationalities['Number of players'] = 1
df_nationalities = df_nationalities.groupby(['Nationality']).sum(['Overall']).reset_index()
df_nationalities['Overall'] = df_nationalities['Overall']/df_nationalities['Number of players']
df_nationalities[['Nationality', 'Overall', 'Number of players']].sort_values('Overall', ascending = False).head()
# Out:
#               Nationality    Overall  Number of players
# 156  United Arab Emirates  77.000000                  1
# 27   Central African Rep.  73.333333                  3
# 77                 Israel  72.142857                 14
# 42     Dominican Republic  72.000000                  2
# 147   São Tomé & Príncipe  72.000000                  1

# %%
df_nationalities[['Nationality', 'Overall', 'Number of players']].loc[df_nationalities['Number of players'] > 50].sort_values('Overall', ascending = False).head()
# Out:
#     Nationality    Overall  Number of players
# 123    Portugal  71.344720                322
# 20       Brazil  71.251511                827
# 2       Algeria  70.633333                 60
# 158     Uruguay  70.429530                149
# 155     Ukraine  70.424658                 73

# %% [markdown]
# #### Nationality of the largest number of players

# %%
df_nationalities[['Nationality', 'Overall', 'Number of players']].sort_values('Number of players', ascending = False).head()
# Out:
#     Nationality    Overall  Number of players
# 46      England  63.429603               1662
# 59      Germany  66.086811               1198
# 139       Spain  69.698694               1072
# 6     Argentina  68.572038                937
# 55       France  67.798687                914

# %% [markdown]
# #### Poland in comparison with other countries

# %%
df_nationalities[['Nationality', 'Overall', 'Number of players']].loc[df_nationalities['Nationality'] == 'Poland']
# Out:
#     Nationality    Overall  Number of players
# 122      Poland  63.228571                350

# %% [markdown]
# ##Charts

# %% [markdown]
# ####Distribution of the skills

# %%
start = 40
end = 100
step = 5

bins = range(start, end+1, step)

plt.hist(df.Overall, bins = bins)
plt.xticks(bins)
plt.title('Distribution of skills (Overall)')
plt.xlabel('Overall skills level')
plt.ylabel('Number of players')

plt.show()

# %% [markdown]
# #### Relation between the price and the overall skills of the player

# %%
type(df['Release Clause'][0])
# Out:
# str

# %%
import re

number = r'\d+\.*\d*'
amounts = r'M|K'

word_re = '\d+\.*\d*(M|K)*'

def word_to_value(word):
  values_dict = {"m": 1000000,
                 "k": 1000,}
  return values_dict[word]

def parse_word_syntax(string):
  value_string = re.search(number, string).group()
  value = float(value_string.replace(',', '')) #Usunięcie przecinka ze stringa w celu konwersji na float
  word = re.search(amounts, string, flags = re.I).group().lower() #flags = re.I -> Ignorowanie wielkich liter w tysiącach, milionach itd.
  word_value = word_to_value(word)
  return value*word_value

def money_conversion(money):
  if money == 'NaN':
    return None

  if isinstance(money, list): #Sprawdzenie czy jest listą
    money = money[0]

  words_syntax = re.search(word_re, money, flags = re.I)

  if words_syntax:
    return parse_word_syntax(words_syntax.group())
  
  else:
    return None

# %%
mon = '226M'
# re.search(number, string).group()

print(money_conversion(mon))
# Out:
# 226000000.0

# %%
df_clause = df.copy()
df_clause['Release Clause'] = [x.strip('€') if type(x) == str else x for x in df_clause['Release Clause']]
df_clause['Release Clause'] = [money_conversion(x) if type(x) == str else x for x in df_clause['Release Clause'] ]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df_clause['Release Clause'][:10])
# Out:
# 0    226500000.0
# 1    127100000.0
# 2    228100000.0
# 3    138600000.0
# 4    196400000.0
# 5    172100000.0
# 6    137400000.0
# 7    164000000.0
# 8    104600000.0
# 9    144500000.0
# Name: Release Clause, dtype: float64

# %%
# df.dropna(subset=['Release Clause'])
df_clause = df_clause[df_clause['Release Clause'] != 'NaN']

# %%
df_clause.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
plt.title('Relation between the release clause and \nthe overall skills of the player')
plt.plot(df_clause['Overall'].loc[df_clause['Overall'] > 65], df_clause['Release Clause'].loc[df_clause['Overall'] > 65])
plt.xlabel('Overall skills')
plt.ylabel('Release clause [mln €]')
plt.show()

# %% [markdown]
# ####Preffered foot

# %%
left = df.loc[df['Preferred Foot'] == 'Left'].count()[0]
right = df.loc[df['Preferred Foot'] == 'Right'].count()[0]

# %%
plt.style.use('ggplot')
explode = (0.1, 0.1)
plt.pie([left, right], labels = ('Left', 'Right'), autopct = '%.2f%%', explode = explode)
plt.title('Foot preferences')
plt.show()

# %% [markdown]
# #### Weight of the players

# %%
#1 pound = 0.45359237 kilograms

# %%
df.Weight = [int(x.strip('lbs')) if type(x) == str else x for x in df.Weight]
# df.Weight = df.Weight * 0.45359237 # zrobić tylko raz :)
df.Weight = round(df.Weight, 1)
df.Weight.head()
# Out:
# 0    72.1
# 1    83.0
# 2    68.0
# 3    76.2
# 4    69.9
# Name: Weight, dtype: float64

# %%
df.Weight.describe()
# Out:
# count    18159.000000
# mean        75.274955
# std          7.071966
# min         49.900000
# 25%         69.900000
# 50%         74.800000
# 75%         79.800000
# max        110.200000
# Name: Weight, dtype: float64

# %%
plt.style.use('ggplot')

light = df.loc[df.Weight < 70].count()[0]
medium = df.loc[(df.Weight >= 70) & (df.Weight < 80)].count()[0]
heavy = df.loc[(df.Weight >80)].count()[0]

weights = [light, medium, heavy]
labels = ['<70 kg', '70-80 kg', '>80 kg']
explode = (0.1, 0.05, 0.1)

plt.title('Weight of the players')
plt.pie(weights, labels = labels, autopct='%.2f%%', explode=explode)
plt.show()

# %% [markdown]
# #### Age and the maximum potential skill growth - difference between actual overall skills and potential depending on the age

# %%
df_pot = df.copy()
df_pot['Difference'] = df_pot['Potential'] - df_pot['Overall']
df_pot = df_pot.groupby(['Age']).mean(['Difference']).reset_index()
df_pot[['Overall', 'Potential', 'Difference', 'Age']].head()
# Out:
#      Overall  Potential  Difference  Age
# 0  54.452381  73.190476   18.738095   16
# 1  56.404844  74.339100   17.934256   17
# 2  57.741803  73.530055   15.788251   18
# 3  59.583008  73.146484   13.563477   19
# 4  61.858871  73.213710   11.354839   20

# %%
import seaborn as sns
sns.set

plt.title("Potential growth of the skills depending on player's age")
plt.plot(df_pot.Age, df_pot.Difference)
plt.xlabel('Age')
plt.ylabel('Potential growth')
plt.show()

# %% [markdown]
# #### Best teams in the game

# %%
df_teams = df.copy()
df_teams = df_teams.groupby(['Club']).mean(['Overall']).sort_values(['Overall'], ascending=False).reset_index()
df_teams[['Club', 'Overall', 'Potential', 'Age']].head()
# Out:
#           Club    Overall  Potential        Age
# 0     Juventus  82.280000  85.520000  27.160000
# 1       Napoli  80.000000  83.440000  25.920000
# 2        Inter  79.750000  81.750000  27.458333
# 3  Real Madrid  78.242424  84.636364  24.030303
# 4        Milan  78.074074  82.555556  25.000000

# %%
top_10 = df_teams[['Club','Overall']][:10]
top_10

plt.figure(figsize = (8,3))
plt.title('Average overall skills in top 10 teams')
plt.xticks(rotation=90)
plt.ylabel('Overall skills')
plt.plot(top_10['Club'], top_10['Overall'])
plt.show()

# %% [markdown]
# #### 3 best italian teams - boxplot

# %%
Juve = df.loc[df.Club == 'Juventus']['Overall']
Napoli = df.loc[df.Club == 'Napoli']['Overall']
Inter = df.loc[df.Club == 'Inter']['Overall']

labels = ['Juventus', 'Napoli', 'Inter']

plt.style.use('default')
plt.figure(figsize = (8,4))
plt.ylabel('Overall skills')
plt.boxplot([Juve, Napoli, Inter], labels=labels)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
