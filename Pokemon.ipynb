# %% [markdown]
# <a href="https://colab.research.google.com/github/leadeeerq/Projects/blob/main/Pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Załadowanie danych

# %%
 import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Projekty/pokemon_data.csv')
# df = pd.read_csv('/content/drive/MyDrive/Projekty/pokemon_data.txt', delimiter = '\t')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ##Eksploracja danych

# %% [markdown]
# ####Wylistowanie kolumn

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
for col in df.columns:
  print(col)
# Out:
# #
# Name
# Type 1
# Type 2
# HP
# Attack
# Defense
# Sp. Atk
# Sp. Def
# Speed
# Generation
# Legendary

# %% [markdown]
# ####Odczyt kilku kolumn

# %%
print(df[['Name', 'HP', 'Generation']])
# Out:
#                       Name  HP  Generation
# 0                Bulbasaur  45           1
# 1                  Ivysaur  60           1
# 2                 Venusaur  80           1
# 3    VenusaurMega Venusaur  80           1
# 4               Charmander  39           1
# ..                     ...  ..         ...
# 795                Diancie  50           6
# 796    DiancieMega Diancie  50           6
# 797    HoopaHoopa Confined  80           6
# 798     HoopaHoopa Unbound  80           6
# 799              Volcanion  80           6
#
# [800 rows x 3 columns]

# %% [markdown]
# ####Pierwsza generacja

# %%
Gen1 = df[df['Generation'] == 1]
HPGen1 = Gen1.sort_values(['HP'], ascending=False)
HPGen1.head()
# Out:
#        #        Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113     Chansey  Normal    NaN  250       5        5       35      105
# 155  143     Snorlax  Normal    NaN  160     110       65       65      110
# 45    40  Wigglytuff  Normal  Fairy  140      70       45       85       50
# 145  134    Vaporeon   Water    NaN  130      65       60      110       95
# 142  131      Lapras   Water    Ice  130      85       80       85       95
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 155     30           1      False
# 45      45           1      False
# 145     65           1      False
# 142     60           1      False

# %%
HP2 = df.sort_values(['HP'], ascending = False)
HP2.head()
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 261     55           2      False
# 121     50           1      False
# 217     33           2      False
# 351     60           3      False
# 655     65           5      False

# %% [markdown]
# ####Odczyt poszczególnych wierszy iloc

# %%
df.iloc[2]
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
print(df.iloc[2:5][['Name', 'HP', 'Type 1']])
# Out:
#                     Name  HP Type 1
# 2               Venusaur  80  Grass
# 3  VenusaurMega Venusaur  80  Grass
# 4             Charmander  39   Fire

# %%
for index, row in df.iterrows():
  if index < 20:
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill

# %% [markdown]
# ####Odczyt konkretnych komórek

# %%
print(df.iloc[99,1])
# Out:
# Gastly

# %% [markdown]
# ####Odczyt za pomocą loc

# %%
df.loc[df['Generation'] == 1]
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass    Poison   45      49       49
# 1      2                Ivysaur    Grass    Poison   60      62       63
# 2      3               Venusaur    Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur    Grass    Poison   80     100      123
# 4      4             Charmander     Fire       NaN   39      52       43
# ..   ...                    ...      ...       ...  ...     ...      ...
# 161  149              Dragonite   Dragon    Flying   91     134       95
# 162  150                 Mewtwo  Psychic       NaN  106     110       90
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 165  151                    Mew  Psychic       NaN  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'] == 'Venusaur']
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 2           1      False

# %% [markdown]
# ##Opis danych

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ##Sortowanie danych

# %%
df.sort_values('Attack', ascending = False)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Attack', 'Defense'], ascending = [0, 1]) #False, True
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# ..   ...                      ...      ...       ...  ...     ...      ...
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ##Modyfikowanie danych

# %% [markdown]
# ####Dodawanie nowych kolumn

# %%
df_mod = df.copy()
df_mod['Att/def ratio'] = df_mod['Attack']/df_mod['Defense']
df_mod.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Att/def ratio
# 0       65     45           1      False       1.000000
# 1       80     60           1      False       0.984127
# 2      100     80           1      False       0.987952
# 3      120     80           1      False       0.813008
# 4       50     65           1      False       1.209302

# %%
# df_mod['Total'] = df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df_mod['Total'] = df.iloc[:, 4:10].sum(axis=1)
df_mod.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Att/def ratio  Total
# 0       65     45           1      False       1.000000    318
# 1       80     60           1      False       0.984127    405
# 2      100     80           1      False       0.987952    525
# 3      120     80           1      False       0.813008    625
# 4       50     65           1      False       1.209302    309

# %% [markdown]
# ####Modyfikowanie pozycji kolumn

# %%
cols = list(df_mod.columns.values)

for c, value in enumerate(cols, 0):
    print(c, value)
# Out:
# 0 #
# 1 Name
# 2 Type 1
# 3 Type 2
# 4 HP
# 5 Attack
# 6 Defense
# 7 Sp. Atk
# 8 Sp. Def
# 9 Speed
# 10 Generation
# 11 Legendary
# 12 Att/def ratio
# 13 Total

# %%
df_mod = df_mod[cols[0:4] + [cols[-1]] + cols[4:13]]
df_mod.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Att/def ratio
# 0       65       65     45           1      False       1.000000
# 1       80       80     60           1      False       0.984127
# 2      100      100     80           1      False       0.987952
# 3      122      120     80           1      False       0.813008
# 4       60       50     65           1      False       1.209302

# %% [markdown]
# ##Eksport danych do csv

# %%
df.to_csv('/content/drive/MyDrive/Projekty/df_mod.csv', index=False)

# %% [markdown]
# ##Filtrowanie danych

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_type = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Fighting')]
df_type
# Out:
#        #        Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 310  286     Breloom  Grass  Fighting  60     130       80       60       60
# 701  640    Virizion  Grass  Fighting  91      90       72       90      129
# 720  652  Chesnaught  Grass  Fighting  88     107      122       74       75
#
#      Speed  Generation  Legendary
# 310     70           3      False
# 701    108           5       True
# 720     64           6      False

# %% [markdown]
# ####Reset indeksu, inplace = True

# %%
df_legendary = df.loc[df['Legendary'] == True]
# print(len(df_legendary))
# df_legendary = df_legendary.reset_index(drop=True)
df_legendary.reset_index(drop = True, inplace = True) #inplace
df_legendary
# Out:
#       #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 0   144             Articuno       Ice    Flying   90      85      100
# 1   145               Zapdos  Electric    Flying   90      90       85
# 2   146              Moltres      Fire    Flying   90     100       90
# 3   150               Mewtwo   Psychic       NaN  106     110       90
# 4   150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..  ...                  ...       ...       ...  ...     ...      ...
# 60  719              Diancie      Rock     Fairy   50     100      150
# 61  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 62  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 63  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 64  721            Volcanion      Fire     Water   80     110      120
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        95      125     85           1       True
# ...

# %%
print(df_mod.Generation.unique())
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# ####Utworzenie listy unikalnych typów

# %%
type1 = df['Type 1'].unique().tolist()
type2 = df['Type 2'].unique().tolist()

in_first = set(type1)
in_second = set(type2)

in_second_but_not_in_first = in_second - in_first

types = type1 + list(in_second_but_not_in_first)
# types = types.dropna()
types = types[0:-1] #Usunięcie nan

for typ in types:
    print(typ)
# Out:
# Grass
# Fire
# Water
# Bug
# Normal
# Poison
# Electric
# Ground
# Fairy
# Fighting
# Psychic
# Rock
# Ghost
# Ice
# Dragon
# Dark
# Steel
# Flying

# %% [markdown]
# ####Odfiltrowanie danych

# %%
df_no_mega = df_mod.loc[~df['Name'].str.contains('Mega')] #Usunięcie poke z "mega" w nazwie. Tylda!
df_no_mega.reset_index(drop = True, inplace = True)
df_no_mega
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 3      4           Charmander     Fire     NaN    309   39      52       43
# 4      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 746  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 747  719              Diancie     Rock   Fairy    600   50     100      150
# 748  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 749  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 750  721            Volcanion     Fire   Water    600   80     110      120
#
# ...

# %% [markdown]
# ####Regex

# %%
import re

# %%
df_no_mega.loc[df['Type 1'].str.contains('Fire|Rock', regex=True)] #Kapitalizacja!
# Out:
#        #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 4      5             Charmeleon      Fire     NaN    405  58      64       58
# 5      6              Charizard      Fire  Flying    534  78      84       78
# 6      7               Squirtle     Water     NaN    314  44      48       65
# 7      8              Wartortle     Water     NaN    405  59      63       80
# 8      9              Blastoise     Water     NaN    530  79      83      100
# ..   ...                    ...       ...     ...    ...  ..     ...      ...
# 723  701               Hawlucha  Fighting  Flying    500  78      92       75
# 730  708               Phantump     Ghost   Grass    309  43      70       48
# 731  709              Trevenant     Ghost   Grass    474  85     110       76
# 735  710    PumpkabooSuper Size     Ghost   Grass    335  59      66       70
# 736  711  GourgeistAverage Size     Ghost   Grass    494  65      90      122
#
# ...

# %%
df_no_mega.loc[df['Type 1'].str.contains('fire|rock', flags=re.I, regex=True)] #Wielkość liter nie ma znaczenia
# Out:
#        #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 4      5             Charmeleon      Fire     NaN    405  58      64       58
# 5      6              Charizard      Fire  Flying    534  78      84       78
# 6      7               Squirtle     Water     NaN    314  44      48       65
# 7      8              Wartortle     Water     NaN    405  59      63       80
# 8      9              Blastoise     Water     NaN    530  79      83      100
# ..   ...                    ...       ...     ...    ...  ..     ...      ...
# 723  701               Hawlucha  Fighting  Flying    500  78      92       75
# 730  708               Phantump     Ghost   Grass    309  43      70       48
# 731  709              Trevenant     Ghost   Grass    474  85     110       76
# 735  710    PumpkabooSuper Size     Ghost   Grass    335  59      66       70
# 736  711  GourgeistAverage Size     Ghost   Grass    494  65      90      122
#
# ...

# %%
df_no_mega.loc[df['Name'].str.contains('^ta[a-z]*', flags = re.I, regex = True)]
# Out:
#        #       Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 122  123    Scyther     Bug  Flying    500  70     110       80       55
# 138  139    Omastar    Rock   Water    495  70      60      125      115
# 299  301   Delcatty  Normal     NaN    380  70      65       65       55
# 516  504     Patrat  Normal     NaN    255  45      55       39       35
# 731  709  Trevenant   Ghost   Grass    474  85     110       76       65
#
#      Sp. Def  Speed  Generation  Legendary  Att/def ratio
# 122       80    105           1      False       1.375000
# 138       70     55           1      False       0.480000
# 299       55     70           3      False       1.000000
# 516       39     42           5      False       1.410256
# 731       82     56           6      False       1.447368

# %% [markdown]
# ##Warunkowe modyfikowanie danych

# %%
# df_no_mega.loc[df_no_mega['Type 1'] == 'Fire', 'Legendary'] = True
# df_cond_mod

# df.loc[df['A'] > 2, 'B'] = new_val

# %%
df_no_mega.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  Att/def ratio
# 0     45           1      False       1.000000
# 1     60           1      False       0.984127
# 2     80           1      False       0.987952
# 3     65           1      False       1.209302
# 4     80           1      False       1.103448

# %%
df_cond = df_no_mega.copy()
df_cond.loc[df_cond['Total'] > 500, ['Legendary', 'Generation']] = ['Test1', 'Test2']
df_cond
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 3      4           Charmander     Fire     NaN    309   39      52       43
# 4      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 746  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 747  719              Diancie     Rock   Fairy    600   50     100      150
# 748  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 749  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 750  721            Volcanion     Fire   Water    600   80     110      120
#
# ...

# %% [markdown]
# ##Agregowanie danych (groupby)

# %%
df_no_mega
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 3      4           Charmander     Fire     NaN    309   39      52       43
# 4      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 746  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 747  719              Diancie     Rock   Fairy    600   50     100      150
# 748  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 749  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 750  721            Volcanion     Fire   Water    600   80     110      120
#
# ...

# %% [markdown]
# ####Średnie wartości dla zagregowanych typów

# %%
df_no_mega.groupby(['Type 1']).mean()
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       346.338462  366.938462  56.076923   65.492308   68.692308
# Dark      479.000000  434.750000  67.178571   86.250000   67.928571
# Dragon    495.500000  517.192308  81.653846  105.884615   80.346154
# Electric  369.119048  436.309524  58.833333   68.333333   65.047619
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  362.720000  404.360000  70.240000   94.720000   64.280000
# Fire      342.354167  445.041667  69.354167   81.125000   65.729167
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     504.000000  430.366667  64.600000   71.033333   81.433333
# Grass     352.575758  410.696970  66.500000   71.227273   68.984848
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       426.217391  427.086957  71.652174   70.695652   71.043478
# Normal    321.138298  394.372340  76.776596   72.329787   58.138298
# ...

# %%
df_no_mega.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    495.500000  517.192308  81.653846  105.884615   80.346154
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Fighting  362.720000  404.360000  70.240000   94.720000   64.280000
# Rock      394.414634  437.804878  64.536585   88.463415   99.756098
# Steel     468.000000  467.304348  64.608696   86.434783  116.391304
# Dark      479.000000  434.750000  67.178571   86.250000   67.928571
# Fire      342.354167  445.041667  69.354167   81.125000   65.729167
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Normal    321.138298  394.372340  76.776596   72.329787   58.138298
# Water     309.794393  422.018692  71.327103   71.794393   70.850467
# Grass     352.575758  410.696970  66.500000   71.227273   68.984848
# Ghost     504.000000  430.366667  64.600000   71.033333   81.433333
# ...

# %% [markdown]
# #### sum(), mean(), count()

# %%
df_no_mega[['Type 1','Legendary']].groupby(['Type 1']).sum().sort_values('Legendary', ascending = False)
# Out:
#           Legendary
# Type 1
# Psychic          12
# Dragon            9
# Fire              5
# Water             4
# Ground            4
# Electric          4
# Steel             4
# Rock              3
# Grass             3
# Dark              2
# Ghost             2
# Ice               2
# Normal            2
# Flying            2
# Fairy             1
# Poison            0
# Fighting          0
# Bug               0

# %%
df_no_mega.groupby(['Type 1', 'Type 2']).count()['#']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     1
#         Fire         2
#         Flying      13
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      4
#         Rock         4
#         Steel        1
# Name: #, Length: 132, dtype: int64

# %% [markdown]
# ##Praca z większymi zbiorami danych

# %% [markdown]
# ####Wczytywanie określonej liczby wierszy na raz

# %%
nrows = 10
for df in pd.read_csv('/content/drive/MyDrive/Projekty/pokemon_data.csv', chunksize=nrows):
  print("Wycinek")
  print(df)
